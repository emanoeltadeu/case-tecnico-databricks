# %% [markdown]
# %md
# ## Setup Environment
#
# Este notebook prepara o ambiente do Databricks definindo schemas e configurando o caminho do volume (Unity Catalog) onde os dados brutos estão armazenados.

# %%
# %run ./utils
# Out:
# # Utils
#
# Notebook contendo funções reutilizáveis para o pipeline de dados.

# %%
# 1. Configuração do Catálogo

print(f"Utilizando o catálogo: {catalog_name}")
# Out:
# Utilizando o catálogo: workspace

# %%
# 2. Criação dos Schemas (Bancos de Dados) Lógicos
# IMPORTANTE: A criação do schema bronze precisa ocorrer antes da criação de qualquer volume dentro dele.
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.bronze")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.silver")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.gold")

print("Schemas criados/verificados com sucesso!")
# Out:
# Schemas criados/verificados com sucesso!

# %%
# 3. Criação do Volume (Unity Catalog) na camada Bronze
# Onde os arquivos físicos (CSV, JSON, XLSX) serão depositados via UI ou API
spark.sql(f"CREATE VOLUME IF NOT EXISTS {catalog_name}.bronze.sources")

print(f"Source Volume Path definido como: {source_volume_path}")
# Out:
# Source Volume Path definido como: /Volumes/workspace/bronze/sources/
